# %%
corpus="""Hello Wecome to my learning blog. I am learning tokenization."""

# %%
print(corpus)
# Out:
# Hello Wecome to my learning blog. I am learning tokenization.

# %%
## Tokenization 
## Sentecnce-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
## List of sentecnes
sent_tokenize(corpus)
# Out:
# ['Hello Wecome to my learning blog.', 'I am learning tokenization.']

# %%
documents=sent_tokenize(corpus)
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Wecome to my learning blog.
# I am learning tokenization.

# %%
## Tokenization
## Paragraph-->words
## Sentence-->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Wecome',
#  'to',
#  'my',
#  'learning',
#  'blog',
#  '.',
#  'I',
#  'am',
#  'learning',
#  'tokenization',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Wecome', 'to', 'my', 'learning', 'blog', '.']
# ['I', 'am', 'learning', 'tokenization', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Wecome',
#  'to',
#  'my',
#  'learning',
#  'blog',
#  '.',
#  'I',
#  'am',
#  'learning',
#  'tokenization',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Wecome',
#  'to',
#  'my',
#  'learning',
#  'blog.',
#  'I',
#  'am',
#  'learning',
#  'tokenization',
#  '.']
