# %% [markdown]
# ### Bag Of Words ###

# %%
data = [
    ("ham", "Hey, are we meeting today"),
    ("ham", "Please call me when you are free"),
    ("spam", "Congratulations! You have won a free ticket"),
    ("spam", "Win cash prizes now, click this link"),
    ("ham", "Let us go for lunch tomorrow"),
    ("spam", "Urgent! Your account has been selected for a reward"),
]

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (91 kB)
# Requirement already satisfied: numpy>=1.26.0 in /Users/pandeyraj/Desktop/Arpita/Python/myproject/venv/lib/python3.12/site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/pandeyraj/Desktop/Arpita/Python/myproject/venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in /Users/pandeyraj/Desktop/Arpita/Python/myproject/venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/pandeyraj/Desktop/Arpita/Python/myproject/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 5.4 MB/s  0:00:025.6 MB/s eta 0:00:0102
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Installing collected packages: pytz, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]━━━━ 1/2 [pandas]
# Successfully installed pandas-2.3.3 pytz-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.DataFrame(data, columns=["label", "message"])
print(df)
# Out:
#   label                                            message
# 0   ham                          Hey, are we meeting today
# 1   ham                   Please call me when you are free
# 2  spam        Congratulations! You have won a free ticket
# 3  spam               Win cash prizes now, click this link
# 4   ham                       Let us go for lunch tomorrow
# 5  spam  Urgent! Your account has been selected for a r...

# %%
df
# Out:
#   label                                            message
# 0   ham                          Hey, are we meeting today
# 1   ham                   Please call me when you are free
# 2  spam        Congratulations! You have won a free ticket
# 3  spam               Win cash prizes now, click this link
# 4   ham                       Let us go for lunch tomorrow
# 5  spam  Urgent! Your account has been selected for a r...

# %%
## Data Cleaning and Preprocessing

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pandeyraj/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
corpus=[]
for i in range(0,len(df)):
    review=re.sub('[^a-zA-z]','',df['message'][i])
    review=review.lower()
    review=review.split()
    review=[ps.stem(word) for word in review if not word in stopwords.words('english')]
    review=''.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['heyarewemeetingtoday',
#  'pleasecallmewhenyouarefre',
#  'congratulationsyouhavewonafreeticket',
#  'wincashprizesnowclickthislink',
#  'letusgoforlunchtomorrow',
#  'urgentyouraccounthasbeenselectedforareward']

# %%
# Option A: Using ! to run shell commands
# !pip install scikit-learn

# Option B: More reliable (works in any environment)
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0.tar.gz (7.3 MB)
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × installing build dependencies for scikit-learn did not run successfully.
#   │ exit code: 1
#   ╰─> [55 lines of output]
#       Collecting meson-python<0.19.0,>=0.17.1
#         Using cached meson_python-0.18.0-py3-none-any.whl.metadata (2.8 kB)
#       Collecting cython<3.3.0,>=3.1.2
#         Using cached cython-3.2.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.5 kB)
#       Collecting numpy<2.4.0,>=2
#         Using cached numpy-2.3.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (62 kB)
#       Collecting scipy<1.17.0,>=1.10.0
#         Using cached scipy-1.16.3.tar.gz (30.6 MB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Installing backend dependencies: started
#         Installing backend dependencies: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Preparing metadata (pyproject.toml) did not run successfully.
#         │ exit code: 1
#         ╰─> [24 lines of output]
#             + meson setup /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-a582_yrz/scipy_80b9489ecbc84695a005109677e516e2 /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-a582_yrz/scipy_80b9489ecbc84695a005109677e516e2/.mesonpy-mrr5sqvu -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=/private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-a582_yrz/scipy_80b9489ecbc84695a005109677e516e2/.mesonpy-mrr5sqvu/meson-python-native-file.ini
#             The Meson build system
#             Version: 1.10.0
#             Source dir: /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-a582_yrz/scipy_80b9489ecbc84695a005109677e516e2
#             Build dir: /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-a582_yrz/scipy_80b9489ecbc84695a005109677e516e2/.mesonpy-mrr5sqvu
#             Build type: native build
#             Project name: scipy
#             Project version: 1.16.3
#             C compiler for the host machine: cc (clang 12.0.5 "Apple clang version 12.0.5 (clang-1205.0.22.11)")
#             C linker for the host machine: cc ld64 650.9
#             C++ compiler for the host machine: c++ (clang 12.0.5 "Apple clang version 12.0.5 (clang-1205.0.22.11)")
#             C++ linker for the host machine: c++ ld64 650.9
#             Cython compiler for the host machine: cython (cython 3.1.8)
#             Host machine cpu family: aarch64
#             Host machine cpu: aarch64
#             Program python found: YES (/Users/pandeyraj/Desktop/Arpita/Python/myproject/venv/bin/python3.12)
#             Did not find pkg-config by name 'pkg-config'
#             Found pkg-config: NO
#             Run-time dependency python found: YES 3.12
#             Program cython found: YES (/private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-build-env-iqplhl4h/overlay/bin/cython)
#
#             ../meson.build:53:4: ERROR: Problem encountered: SciPy requires clang >= 15.0
#
#             A full log can be found at /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-a582_yrz/scipy_80b9489ecbc84695a005109677e516e2/.mesonpy-mrr5sqvu/meson-logs/meson-log.txt
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       × Encountered error while generating package metadata.
#       ╰─> scipy
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'scikit-learn' when installing build dependencies for scikit-learn
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0.tar.gz (7.3 MB)
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × installing build dependencies for scikit-learn did not run successfully.
#   │ exit code: 1
#   ╰─> [55 lines of output]
#       Collecting meson-python<0.19.0,>=0.17.1
#         Using cached meson_python-0.18.0-py3-none-any.whl.metadata (2.8 kB)
#       Collecting cython<3.3.0,>=3.1.2
#         Using cached cython-3.2.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.5 kB)
#       Collecting numpy<2.4.0,>=2
#         Using cached numpy-2.3.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (62 kB)
#       Collecting scipy<1.17.0,>=1.10.0
#         Using cached scipy-1.16.3.tar.gz (30.6 MB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Installing backend dependencies: started
#         Installing backend dependencies: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Preparing metadata (pyproject.toml) did not run successfully.
#         │ exit code: 1
#         ╰─> [24 lines of output]
#             + meson setup /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-c0ya86j4/scipy_d754d4cf832a486bb0e755ecc4a24b79 /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-c0ya86j4/scipy_d754d4cf832a486bb0e755ecc4a24b79/.mesonpy-bef8elc2 -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=/private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-c0ya86j4/scipy_d754d4cf832a486bb0e755ecc4a24b79/.mesonpy-bef8elc2/meson-python-native-file.ini
#             The Meson build system
#             Version: 1.10.0
#             Source dir: /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-c0ya86j4/scipy_d754d4cf832a486bb0e755ecc4a24b79
#             Build dir: /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-c0ya86j4/scipy_d754d4cf832a486bb0e755ecc4a24b79/.mesonpy-bef8elc2
#             Build type: native build
#             Project name: scipy
#             Project version: 1.16.3
#             C compiler for the host machine: cc (clang 12.0.5 "Apple clang version 12.0.5 (clang-1205.0.22.11)")
#             C linker for the host machine: cc ld64 650.9
#             C++ compiler for the host machine: c++ (clang 12.0.5 "Apple clang version 12.0.5 (clang-1205.0.22.11)")
#             C++ linker for the host machine: c++ ld64 650.9
#             Cython compiler for the host machine: cython (cython 3.1.8)
#             Host machine cpu family: aarch64
#             Host machine cpu: aarch64
#             Program python found: YES (/Users/pandeyraj/Desktop/Arpita/Python/myproject/venv/bin/python3.12)
#             Did not find pkg-config by name 'pkg-config'
#             Found pkg-config: NO
#             Run-time dependency python found: YES 3.12
#             Program cython found: YES (/private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-build-env-9ziw1nlb/overlay/bin/cython)
#
#             ../meson.build:53:4: ERROR: Problem encountered: SciPy requires clang >= 15.0
#
#             A full log can be found at /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-c0ya86j4/scipy_d754d4cf832a486bb0e755ecc4a24b79/.mesonpy-bef8elc2/meson-logs/meson-log.txt
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       × Encountered error while generating package metadata.
#       ╰─> scipy
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'scikit-learn' when installing build dependencies for scikit-learn

# %%
brew install python
# Out:
#   Cell In[43], line 1
#     brew install python
#          ^
# SyntaxError: invalid syntax

# %%
## Create Bag Of Words Model ##
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(mx_features=2500)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 2
#       1 ## Create Bag Of Words Model ##
# ----> 2 from sklearn.feature_extraction.text import CountVectorizer
#       3 cv=CountVectorizer(mx_features=2500)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
cv.fit_transform(corpus).toarray()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 cv.fit_transform(corpus).toarray()
#
# NameError: name 'cv' is not defined

# %%
pip3 install scikit-learn
# Out:
#   Cell In[34], line 1
#     pip3 install scikit-learn
#          ^
# SyntaxError: invalid syntax
