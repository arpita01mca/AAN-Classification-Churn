# %% [markdown]
# ### Parts Of Speech Tag ###

# %%
## Speech of APJ Abdul Kalam ##
paragraph=""" Today, I stand before you to speak about the Vision of India—a vision of a strong, self-reliant, inclusive, and developed nation.
India is not just a land of ancient history and rich culture; it is a nation of immense potential. With more than half of our population below the age of 35, the youth of India are the driving force of our future. The vision of India lies in empowering this youth with education, skills, and values.
A developed India is one where knowledge is power. Education must not only help us earn a living but also teach us how to think, innovate, and serve society. Science and technology should reach the villages, farmers, and small industries, ensuring that development touches every citizen.
The vision of India also includes economic strength with social harmony. Growth must be inclusive—bridging the gap between the rich and the poor, between urban and rural India. Every citizen should have access to healthcare, clean water, and equal opportunities.
A truly developed India is built on ethical leadership and responsible citizenship. Corruption, discrimination, and violence weaken the nation. Honesty, unity, and respect for diversity strengthen it. As citizens, we must do our duty before asking for our rights.
India’s vision is also a peaceful nation that contributes to global progress. We believe in “Vasudhaiva Kutumbakam”—the world is one family. Through innovation, diplomacy, and compassion, India can lead the world towards peace and sustainability.
Friends, the vision of India is not the responsibility of the government alone—it is our collective responsibility. Each student, teacher, worker, and leader must contribute through dedication and hard work.
Let us dream of an India that is educated, healthy, prosperous, and united.Let us work together to turn that dream into reality.
The future of India begins with us.Jai Hind. """

# %%
from nltk.corpus import stopwords
sentecnces=nltk.sent_tokenize(paragraph)

# %%
import nltk
sentences=nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# [' Today, I stand before you to speak about the Vision of India—a vision of a strong, self-reliant, inclusive, and developed nation.',
#  'India is not just a land of ancient history and rich culture; it is a nation of immense potential.',
#  'With more than half of our population below the age of 35, the youth of India are the driving force of our future.',
#  'The vision of India lies in empowering this youth with education, skills, and values.',
#  'A developed India is one where knowledge is power.',
#  'Education must not only help us earn a living but also teach us how to think, innovate, and serve society.',
#  'Science and technology should reach the villages, farmers, and small industries, ensuring that development touches every citizen.',
#  'The vision of India also includes economic strength with social harmony.',
#  'Growth must be inclusive—bridging the gap between the rich and the poor, between urban and rural India.',
#  'Every citizen should have access to healthcare, clean water, and equal opportunities.',
#  'A truly developed India is built on ethical leadership and responsible citizenship.',
#  'Corruption, discrimination, and violence weaken the nation.',
#  'Honesty, unity, and respect for diversity strengthen it.',
#  'As citizens, we must do our duty before asking for our rights.',
#  'India’s vision is also a peaceful nation that contributes to global progress.',
#  'We believe in “Vasudhaiva Kutumbakam”—the world is one family.',
#  'Through innovation, diplomacy, and compassion, India can lead the world towards peace and sustainability.',
#  'Friends, the vision of India is not the responsibility of the government alone—it is our collective responsibility.',
#  'Each student, teacher, worker, and leader must contribute through dedication and hard work.',
#  'Let us dream of an India that is educated, healthy, prosperous, and united.Let us work together to turn that dream into reality.',
#  'The future of India begins with us.Jai Hind.']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/pandeyraj/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
## We will find the Pos Tag
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words= [word for word in words if word not in set(stopwords.words('English'))]
    ##sentences[i]=' '.join(words)#conveting all the list of words into sentences
    pos_tag=nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('Today', 'NN'), (',', ','), ('I', 'PRP'), ('stand', 'VBP'), ('speak', 'JJ'), ('Vision', 'NNP'), ('India—a', 'NNP'), ('vision', 'NN'), ('strong', 'JJ'), (',', ','), ('self-reliant', 'JJ'), (',', ','), ('inclusive', 'JJ'), (',', ','), ('developed', 'JJ'), ('nation', 'NN'), ('.', '.')]
# [('India', 'NNP'), ('land', 'NN'), ('ancient', 'NN'), ('history', 'NN'), ('rich', 'JJ'), ('culture', 'NN'), (';', ':'), ('nation', 'NN'), ('immense', 'IN'), ('potential', 'NN'), ('.', '.')]
# [('With', 'IN'), ('half', 'DT'), ('population', 'NN'), ('age', 'NN'), ('35', 'CD'), (',', ','), ('youth', 'RB'), ('India', 'NNP'), ('driving', 'VBG'), ('force', 'NN'), ('future', 'NN'), ('.', '.')]
# [('The', 'DT'), ('vision', 'NN'), ('India', 'NNP'), ('lies', 'VBZ'), ('empowering', 'VBG'), ('youth', 'JJ'), ('education', 'NN'), (',', ','), ('skills', 'NNS'), (',', ','), ('values', 'NNS'), ('.', '.')]
# [('A', 'DT'), ('developed', 'JJ'), ('India', 'NNP'), ('one', 'CD'), ('knowledge', 'NN'), ('power', 'NN'), ('.', '.')]
# [('Education', 'NN'), ('must', 'MD'), ('help', 'VB'), ('us', 'PRP'), ('earn', 'VB'), ('living', 'NN'), ('also', 'RB'), ('teach', 'VBP'), ('us', 'PRP'), ('think', 'VBP'), (',', ','), ('innovate', 'VBP'), (',', ','), ('serve', 'VBP'), ('society', 'NN'), ('.', '.')]
# [('Science', 'NNP'), ('technology', 'NN'), ('reach', 'NN'), ('villages', 'NNS'), (',', ','), ('farmers', 'NNS'), (',', ','), ('small', 'JJ'), ('industries', 'NNS'), (',', ','), ('ensuring', 'VBG'), ('development', 'NN'), ('touches', 'NNS'), ('every', 'DT'), ('citizen', 'NN'), ('.', '.')]
# [('The', 'DT'), ('vision', 'NN'), ('India', 'NNP'), ('also', 'RB'), ('includes', 'VBZ'), ('economic', 'JJ'), ('strength', 'NN'), ('social', 'JJ'), ('harmony', 'NN'), ('.', '.')]
# [('Growth', 'NNP'), ('must', 'MD'), ('inclusive—bridging', 'VB'), ('gap', 'NN'), ('rich', 'JJ'), ('poor', 'JJ'), (',', ','), ('urban', 'JJ'), ('rural', 'JJ'), ('India', 'NNP'), ('.', '.')]
# [('Every', 'DT'), ('citizen', 'NN'), ('access', 'NN'), ('healthcare', 'NN'), (',', ','), ('clean', 'JJ'), ('water', 'NN'), (',', ','), ('equal', 'JJ'), ('opportunities', 'NNS'), ('.', '.')]
# [('A', 'DT'), ('truly', 'NN'), ('developed', 'VBD'), ('India', 'NNP'), ('built', 'VBD'), ('ethical', 'JJ'), ('leadership', 'NN'), ('responsible', 'JJ'), ('citizenship', 'NN'), ('.', '.')]
# [('Corruption', 'NN'), (',', ','), ('discrimination', 'NN'), (',', ','), ('violence', 'NN'), ('weaken', 'JJ'), ('nation', 'NN'), ('.', '.')]
# [('Honesty', 'NNP'), (',', ','), ('unity', 'NN'), (',', ','), ('respect', 'JJ'), ('diversity', 'NN'), ('strengthen', 'NN'), ('.', '.')]
# [('As', 'IN'), ('citizens', 'NNS'), (',', ','), ('must', 'MD'), ('duty', 'VB'), ('asking', 'VBG'), ('rights', 'NNS'), ('.', '.')]
# [('India', 'NNP'), ('’', 'NNP'), ('vision', 'NN'), ('also', 'RB'), ('peaceful', 'JJ'), ('nation', 'NN'), ('contributes', 'NNS'), ('global', 'JJ'), ('progress', 'NN'), ('.', '.')]
# [('We', 'PRP'), ('believe', 'VBP'), ('“', 'JJ'), ('Vasudhaiva', 'NNP'), ('Kutumbakam', 'NNP'), ('”', 'NNP'), ('—the', 'NNP'), ('world', 'NN'), ('one', 'CD'), ('family', 'NN'), ('.', '.')]
# [('Through', 'IN'), ('innovation', 'NN'), (',', ','), ('diplomacy', 'NN'), (',', ','), ('compassion', 'NN'), (',', ','), ('India', 'NNP'), ('lead', 'VBP'), ('world', 'NN'), ('towards', 'NNS'), ('peace', 'VBP'), ('sustainability', 'NN'), ('.', '.')]
# [('Friends', 'NNS'), (',', ','), ('vision', 'NN'), ('India', 'NNP'), ('responsibility', 'NN'), ('government', 'NN'), ('alone—it', 'VBD'), ('collective', 'JJ'), ('responsibility', 'NN'), ('.', '.')]
# [('Each', 'DT'), ('student', 'NN'), (',', ','), ('teacher', 'RB'), (',', ','), ('worker', 'NN'), (',', ','), ('leader', 'NN'), ('must', 'MD'), ('contribute', 'VB'), ('dedication', 'NN'), ('hard', 'JJ'), ('work', 'NN'), ('.', '.')]
# [('Let', 'VB'), ('us', 'PRP'), ('dream', 'VB'), ('India', 'NNP'), ('educated', 'VBN'), (',', ','), ('healthy', 'JJ'), (',', ','), ('prosperous', 'JJ'), (',', ','), ('united.Let', 'JJ'), ('us', 'PRP'), ('work', 'VBP'), ('together', 'RB'), ('turn', 'VBP'), ('dream', 'NN'), ('reality', 'NN'), ('.', '.')]
# [('The', 'DT'), ('future', 'NN'), ('India', 'NNP'), ('begins', 'VBZ'), ('us.Jai', 'JJ'), ('Hind', 'NNP'), ('.', '.')]

# %%
import nltk
from nltk import word_tokenize, pos_tag_sents

sentence = "Taj Mahal is a beautiful Monument"

# Step 1: tokenize
tokens = word_tokenize(sentence)

# Step 2: wrap inside a list
result = pos_tag_sents([tokens])

print(result)
# Out:
# [[('Taj', 'NNP'), ('Mahal', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('Monument', 'NN')]]
