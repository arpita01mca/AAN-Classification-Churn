# %% [markdown]
# ### WordToVec Practical ###

# %%
pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting numpy>=1.18.5 (from gensim)
#   Using cached numpy-2.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting scipy>=1.7.0 (from gensim)
#   Using cached scipy-1.17.0.tar.gz (30.4 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [24 lines of output]
#       + meson setup /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-yai6j38z/scipy_f204a68561e74a749822af281217af4a /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-yai6j38z/scipy_f204a68561e74a749822af281217af4a/.mesonpy-y_uubtk_ -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=/private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-yai6j38z/scipy_f204a68561e74a749822af281217af4a/.mesonpy-y_uubtk_/meson-python-native-file.ini
#       The Meson build system
#       Version: 1.10.1
#       Source dir: /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-yai6j38z/scipy_f204a68561e74a749822af281217af4a
#       Build dir: /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-yai6j38z/scipy_f204a68561e74a749822af281217af4a/.mesonpy-y_uubtk_
#       Build type: native build
#       Project name: scipy
#       Project version: 1.17.0
#       C compiler for the host machine: cc (clang 12.0.5 "Apple clang version 12.0.5 (clang-1205.0.22.11)")
#       C linker for the host machine: cc ld64 650.9
#       C++ compiler for the host machine: c++ (clang 12.0.5 "Apple clang version 12.0.5 (clang-1205.0.22.11)")
#       C++ linker for the host machine: c++ ld64 650.9
#       Cython compiler for the host machine: cython (cython 3.2.4)
#       Host machine cpu family: aarch64
#       Host machine cpu: aarch64
#       Program python found: YES (/Users/pandeyraj/miniforge3/bin/python)
#       Did not find pkg-config by name 'pkg-config'
#       Found pkg-config: NO
#       Run-time dependency python found: YES 3.12
#       Program cython found: YES (/private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-build-env-u_3spjn3/overlay/bin/cython)
#
#       ../meson.build:53:4: ERROR: Problem encountered: SciPy requires clang >= 15.0
#
#       A full log can be found at /private/var/folders/mz/8mc4zw410ds970yk8zc78b9c0000gn/T/pip-install-yai6j38z/scipy_f204a68561e74a749822af281217af4a/.mesonpy-y_uubtk_/meson-logs/meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> scipy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')
vec_king = wv['king']

# %%
print(vec_king)

# %%
vec_king.shape
