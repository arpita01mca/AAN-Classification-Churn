# %% [markdown]
# ## ANN Implementation

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
conda activate tf310
which python
python --version
# Out:
#   Cell In[2], line 1
#     conda activate tf310
#           ^
# SyntaxError: invalid syntax

# %%
conda activate tf310
# Out:
# CondaError: Run 'conda init' before 'conda activate'
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda init tf310
# Out:
# usage: conda init [-h] [--all] [--condabin] [--user] [--no-user] [--system]
#                   [--reverse] [--json] [--console CONSOLE] [-v] [-q] [-d]
#                   [SHELLS ...]
# conda init: error: argument SHELLS: invalid choice: 'tf310' (choose from bash, fish, tcsh, xonsh, zsh, powershell)
#
# Note: you may need to restart the kernel to use updated packages.
